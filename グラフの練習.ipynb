# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
x = np.linspace(start=-2,stop=2,num=100)
y = 3*x**5-2*x**4 -10*x +5

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(x,y,marker='.')

# %%
y
# Out:
# array([-1.05700000e+04, -3.08193670e+03, -5.82442209e+02, -3.23456790e+01,
#         1.02062694e+01, -5.87308845e-01,  1.14814815e+01,  3.54292537e+02,
#         2.17706092e+03,  8.08000000e+03])
